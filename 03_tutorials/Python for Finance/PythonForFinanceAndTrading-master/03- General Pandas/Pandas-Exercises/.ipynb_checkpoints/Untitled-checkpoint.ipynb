# %%
import pandas as pd

# %%
banks=pd.read_csv("banklist.csv")

# %%
banks.head()
# Out:
#                                            Bank Name                City  ST  \
# 0                                Fayette County Bank          Saint Elmo  IL
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 2                                     First NBC Bank         New Orleans  LA
# 3                                      Proficio Bank  Cottonwood Heights  UT
# 4                      Seaway Bank and Trust Company             Chicago  IL
#
#     CERT                Acquiring Institution Closing Date Updated Date
# 0   1802            United Fidelity Bank, fsb    26-May-17     1-Jun-17
# 1  30003  First-Citizens Bank & Trust Company     5-May-17     1-Jun-17
# 2  58302                         Whitney Bank    28-Apr-17    23-May-17
# 3  35495                    Cache Valley Bank     3-Mar-17    18-May-17
# 4  19328                  State Bank of Texas    27-Jan-17    18-May-17

# %%
# Out:
# array(['IL', 'WI', 'LA', 'UT', 'NJ', 'AR', 'GA', 'PA', 'TN', 'WA', 'CO',
#        'PR', 'FL', 'MN', 'CA', 'MD', 'OK', 'OH', 'SC', 'VA', 'ID', 'TX',
#        'CT', 'AZ', 'NV', 'NC', 'KY', 'MO', 'KS', 'AL', 'MI', 'IN', 'IA',
#        'NE', 'MS', 'NM', 'OR', 'NY', 'MA', 'SD', 'WY', 'WV', 'NH', 'HI'],
#       dtype=object)

# %%
banks.groupby("Acquiring Institution").count().sort_values("Bank Name",ascending=False).iloc[1:6]["Bank Name"]
# Out:
# Acquiring Institution
# State Bank and Trust Company           12
# First-Citizens Bank & Trust Company    11
# Ameris Bank                            10
# U.S. Bank N.A.                          9
# Community & Southern Bank               8
# Name: Bank Name, dtype: int64

# %%
#banks.sort_values("ST")

# %%
banks["ST"].value_counts()
# Out:
# GA    93
# FL    75
# IL    67
# CA    41
# MN    23
# WA    19
# AZ    16
# MO    16
# MI    14
# TX    12
# NV    12
# WI    11
# CO    10
# PA    10
# MD    10
# SC    10
# KS     9
# UT     8
# OH     8
# TN     7
# NJ     7
# AL     7
# NC     7
# OK     7
# OR     6
# NY     5
# VA     5
# PR     4
# LA     4
# NE     3
# NM     3
# IN     3
# AR     3
# MS     2
# IA     2
# KY     2
# CT     2
# ID     2
# WY     1
# NH     1
# MA     1
# WV     1
# SD     1
# HI     1
# Name: ST, dtype: int64

# %%
banks["ST"].count()
# Out:
# 551

# %%
banks
# Out:
#                                              Bank Name                City  \
# 0                                  Fayette County Bank          Saint Elmo
# 1    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 2                                       First NBC Bank         New Orleans
# 3                                        Proficio Bank  Cottonwood Heights
# 4                        Seaway Bank and Trust Company             Chicago
# 5                               Harvest Community Bank          Pennsville
# 6                                          Allied Bank            Mulberry
# 7                         The Woodbury Banking Company            Woodbury
# 8                               First CornerStone Bank     King of Prussia
# 9                                   Trust Company Bank             Memphis
# 10                          North Milwaukee State Bank           Milwaukee
# ...

# %%
banks[banks
# Out:
# 0                United Fidelity Bank, fsb
# 1      First-Citizens Bank & Trust Company
# 2                             Whitney Bank
# 3                        Cache Valley Bank
# 4                      State Bank of Texas
# 5      First-Citizens Bank & Trust Company
# 6                             Today's Bank
# 7                              United Bank
# 8      First-Citizens Bank & Trust Company
# 9               The Bank of Fayette County
# 10     First-Citizens Bank & Trust Company
# 11                          Twin City Bank
# 12                           Fidelity Bank
# 13               United Fidelity Bank, fsb
# 14                Republic Bank of Chicago
# 15            Banco Popular de Puerto Rico
# 16     First-Citizens Bank & Trust Company
# 17               United Fidelity Bank, fsb
# 18                          First NBC Bank
# 19                               BankVista
# 20       Bank of Southern California, N.A.
# 21                     State Bank of Texas
# ...

# %%
banks
# Out:
#                                              Bank Name                City  \
# 0                                  Fayette County Bank          Saint Elmo
# 1    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 2                                       First NBC Bank         New Orleans
# 3                                        Proficio Bank  Cottonwood Heights
# 4                        Seaway Bank and Trust Company             Chicago
# 5                               Harvest Community Bank          Pennsville
# 6                                          Allied Bank            Mulberry
# 7                         The Woodbury Banking Company            Woodbury
# 8                               First CornerStone Bank     King of Prussia
# 9                                   Trust Company Bank             Memphis
# 10                          North Milwaukee State Bank           Milwaukee
# ...

# %%
banks[(banks["Acquiring Institution"]=="State Bank of Texas") & (banks["ST"]=="TX")]
# Out:
# Bank Name                1
# City                     1
# ST                       1
# CERT                     1
# Acquiring Institution    1
# Closing Date             1
# Updated Date             1
# dtype: int64

# %%
banks[banks["ST"]=="CA"]["City"].value_counts().head(1)
# Out:
# Los Angeles    4
# Name: City, dtype: int64

# %%
banks[banks["ST"]=="CA"].groupby("City").count().sort_values("Bank Name",ascending=False).head(1)
# Out:
#              Bank Name  ST  CERT  Acquiring Institution  Closing Date  \
# City
# Los Angeles          4   4     4                      4             4
#
#              Updated Date
# City
# Los Angeles             4

# %%
sum(banks["Bank Name"].apply(lambda x: "Bank" not in x))
# Out:
# 14
